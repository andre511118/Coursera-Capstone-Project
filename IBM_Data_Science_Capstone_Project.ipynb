# %% [markdown]
# # IBM Data Science Capstone Project Week 4 + 5

# %% [markdown]
# ## Optimal location for a Sushi restaurant near subway station in Stuttgart

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find an optimal location for a Sushi restaurant.
#
# Stuttgart is a beautiful city, but like all the other big cities, it has frequent traffic jams. Fortunately it good subway system to connect all parts of cities. Sushi is very delicious food liked by young people, who also like to travel with public traffic like subway. Therefore in project we will use subway station instead of neighbourhood to explore the restaurants.
#
# The first criteria for a good location of restaurant should be number of people who is passing by. In case of Stuttgart is should be near the city center. The second criteria should be the number of existing restaurants, the best location has been choosen thousand times by other people, we can trust it is a good location if there are many restaurants.
# But we can avoid Sushi restaurant. We don't want to open a Sushi restaurant near a existing one. This is then the third criteria.
#
# We will use data analysis and machine learning methodology to explore and find out the possible location, which meet the criteria we defined.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# We need the following data for our problem:
# * the location of all subway stations in stuttgart, this can be found in Wikipedia by using Web Scraping of HTML
# * total number of existing restaurants near subway station, it will be obtained using **Foursquare API**
# * total number of existing Sushi restaurants near subway station, it can also be find out using **Foursquare API**
# * distance of subway from city center, this can be calculated using the infomation of subway station from the Wikipedia

# %% [markdown]
# #### Web Scraping of the location data of Stuttgart subway station from Wikipedia

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

from bs4 import BeautifulSoup 

import requests # library to handle requests

# %%
#wikipedia page of subway stations
url = "https://de.wikipedia.org/wiki/Liste_der_Haltestellen_der_Stadtbahn_Stuttgart"
data = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")

# %%
table_contents=[] # define empty date
table=soup.find('table') # find table
table_body = table.find('tbody')

rows = table_body.find_all('tr') 
#get column name from the first row
column = rows[0] #get column
column_name = column.find_all('th')
column_name = [ele.text.strip() for ele in column_name]
# get the content of the table
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    table_contents.append(cols) 

# create pandas dataframe
dataframe= pd.DataFrame(table_contents)
# change the column name
dataframe.columns = column_name
dataframe.head(10)
# Out:
#                                                 Name  ... Bild
# 0      Antwerpener Straße48° 48′ 30″ N, 9° 14′ 35″ O  ...
# 1       Arndt-/Spittastraße48° 46′ 30″ N, 9° 9′ 3″ O  ...
# 2        Augsburger Platz48° 48′ 21″ N, 9° 13′ 51″ O  ...
# 3                Auwiesen48° 50′ 22″ N, 9° 13′ 30″ O  ...
# 4  Bad Cannstatt Wilhelmsplatz48° 48′ 10″ N, 9° 1...  ...
# 5  Bad Cannstatt Wilhelmsplatz48° 48′ 12″ N, 9° 1...  ...
# 6           Beethovenstraße48° 46′ 38″ N, 9° 8′ 0″ O  ...
# 7  Bergfriedhof (Merz-Akademie)48° 47′ 21″ N, 9° ...  ...
# 8            Bergheimer Hof48° 48′ 15″ N, 9° 6′ 3″ O  ...
# 9  Berliner Platz (Hohe Straße)48° 46′ 38″ N, 9° ...  ...
#
# [10 rows x 9 columns]

# %%
#choose only station within Stuttgart
index = dataframe[dataframe['Stadt']!='Stuttgart'].index
dataframe.drop(index , inplace=True)
dataframe.head(10)
# Out:
#                                                 Name  ... Bild
# 0      Antwerpener Straße48° 48′ 30″ N, 9° 14′ 35″ O  ...
# 1       Arndt-/Spittastraße48° 46′ 30″ N, 9° 9′ 3″ O  ...
# 2        Augsburger Platz48° 48′ 21″ N, 9° 13′ 51″ O  ...
# 3                Auwiesen48° 50′ 22″ N, 9° 13′ 30″ O  ...
# 4  Bad Cannstatt Wilhelmsplatz48° 48′ 10″ N, 9° 1...  ...
# 5  Bad Cannstatt Wilhelmsplatz48° 48′ 12″ N, 9° 1...  ...
# 6           Beethovenstraße48° 46′ 38″ N, 9° 8′ 0″ O  ...
# 7  Bergfriedhof (Merz-Akademie)48° 47′ 21″ N, 9° ...  ...
# 8            Bergheimer Hof48° 48′ 15″ N, 9° 6′ 3″ O  ...
# 9  Berliner Platz (Hohe Straße)48° 46′ 38″ N, 9° ...  ...
#
# [10 rows x 9 columns]

# %%
#funtion to coversion of coordination
def converseCoordinate(degree,minute,second):
    coordDec = degree + minute/60 + second/3600
    return coordDec

# %%
# define the dataframe columns
column_names = ['Subway Station', 'Line', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
subway_station = pd.DataFrame(columns=column_names)

# %%
# read and prepare the information of subway station from the row data
for index, rows in dataframe.iterrows():
    #cell['Borough'] = (row.span.text).split('(')[0]
    #cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
    stationID = rows['Name'][0: rows['Name'].find('48')]
    coordinate = rows['Name'][rows['Name'].find('48'):]
    coordinate_lat = coordinate.split('N,')[0]
    coordinate_lon = coordinate.split('N,')[1]
    #print(coordinate_lat)
    #print(coordinate_lon)
    minute_lat = int(coordinate_lat[coordinate_lat.find('°')+1:coordinate_lat.find('′')])
    second_lat = int(coordinate_lat[coordinate_lat.find('′')+1:coordinate_lat.find('″')])
    minute_lon = int(coordinate_lon[coordinate_lat.find('°')+1:coordinate_lon.find('′')])
    second_lon = int(coordinate_lon[coordinate_lat.find('′')+1:coordinate_lon.find('″')])
    station_lat = converseCoordinate(48,minute_lat,second_lat)
    station_lon = converseCoordinate(9,minute_lon,second_lon)
    #print(station_lat)
    #print(station_lon)
    lineID = [i.replace('0','') for i in rows['Linie'].split(' ') if i.find('U')!=-1]
    #print(lineID)
    neighborhood = rows['Stadtteil (Stadtbezirk)'][rows['Stadtteil (Stadtbezirk)'].find('(')+1:rows['Stadtteil (Stadtbezirk)'].find(')')]
    #print(neighborhood)

    subway_station = subway_station.append({'Subway Station': stationID,
                                            'Line': lineID,
                                            'Neighborhood': neighborhood,
                                            'Latitude': station_lat,
                                            'Longitude': station_lon}, ignore_index=True)

# %%
subway_station.shape
# Out:
# (188, 5)

# %%
subway_station.head(10)
# Out:
#                  Subway Station                Line  ...   Latitude  Longitude
# 0            Antwerpener Straße           [U1, U16]  ...  48.808333   9.243056
# 1           Arndt-/Spittastraße       [U2, U9, U14]  ...  48.775000   9.150833
# 2              Augsburger Platz           [U1, U16]  ...  48.805833   9.230833
# 3                      Auwiesen          [U12, U14]  ...  48.839444   9.225000
# 4   Bad Cannstatt Wilhelmsplatz       [U1, U2, U19]  ...  48.802778   9.215833
# 5   Bad Cannstatt Wilhelmsplatz          [U13, U16]  ...  48.803333   9.215556
# 6               Beethovenstraße            [U2, U9]  ...  48.777222   9.133333
# 7  Bergfriedhof (Merz-Akademie)            [U4, U9]  ...  48.789167   9.205556
# 8                Bergheimer Hof           [U6, U16]  ...  48.804167   9.100833
# 9  Berliner Platz (Hohe Straße)  [U2, U4, U14, U14]  ...  48.777222   9.168611
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will explore the restaurant near each subway stations with Foursquare API. And visualize the location with Folium map.
#
# we will count the number of total restaurant and the total Sushi restaurants near the subway station.
#
# The Distance of the subway station to the city center will be calculated and considered in the analysis.
#
# we will use K means to cluster the subway station base on the all information above. The classification will be visualized the city map.
#
# Base on the classification we can find a group of candidate of subway station which we can open a Sushi restaurant near them.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Import the libaries

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from geopy.geocoders import Nominatim

# %% [markdown]
# <h4>Getting Stuttgart Coordinates from Geopy library</h4>

# %%
address = 'Stuttgart, Germany'

geolocator = Nominatim(user_agent="can_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Stuttgart are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Stuttgart are 48.7784485, 9.1800132.

# %% [markdown]
# Visualize the location of the Subway Stations

# %%
# create map of New York using latitude and longitude values
map_stuttgart = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, station, neighborhood in zip(subway_station['Latitude'], subway_station['Longitude'], subway_station['Subway Station'], subway_station['Neighborhood']):
    label = '{}, {}'.format(station, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_stuttgart)  
    
map_stuttgart
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_ef2f9cee41774189b81f193efd3e7d7f%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ef2f9cee41774189b81f193efd3e7d7f%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_ef2f9cee41774189b81f193efd3e7d7f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_ef2f9cee41774189b81f193efd3e7d7f%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.7784485%2C%209.1800132%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_633c0aa6186a49cb943337cf1421abd6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %%
CLIENT_ID = 'UCAD22UHIEXLJT5GFMM1PLTLT1IF0WP1DVVYQU21DQQYJ5FW' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UCAD22UHIEXLJT5GFMM1PLTLT1IF0WP1DVVYQU21DQQYJ5FW
# CLIENT_SECRET:YGTTPPE5VBXUNUMNFNAROUT4HPCTD0SH4JIJFDE0ZS3KB3YL

# %% [markdown]
# #### Creating a function to find vanues of all the subway station within 300 meter

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=300):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            100)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Subway Station', 
                  'Subway Station Latitude', 
                  'Subway Station Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
stuttgart_venues = getNearbyVenues(names=subway_station['Subway Station'],
                                   latitudes=subway_station['Latitude'],
                                   longitudes=subway_station['Longitude'],
                                  )
# Out:
# Antwerpener Straße
# Arndt-/Spittastraße
# Augsburger Platz
# Auwiesen
# Bad Cannstatt Wilhelmsplatz
# Bad Cannstatt Wilhelmsplatz
# Beethovenstraße
# Bergfriedhof (Merz-Akademie)
# Bergheimer Hof
# Berliner Platz (Hohe Straße)
# Berliner Platz (Liederhalle)
# Berliner Platz (Liederhalle)
# Beskidenstraße
# Bihlplatz
# Blick
# Bopser
# Borsigstraße
# Botnang
# Bottroper Straße (BiL-Schulen)
# Börsenplatz (L-Bank)
# Brendle (Großmarkt)
# Bubenbad (IB-Jugendgästehaus)
# Budapester Platz
# Cannstatter Wasen
# Charlottenplatz (Ebene -1)
# Charlottenplatz (Ebene -2)
# Daimlerplatz
# Degerloch
# Degerloch Albstraße
# Dobelstraße
# Dürrlewang
# Ebitzweg
# Elbestraße
# Eltinger Straße
# EnBW-City
# Engelboldstraße
# Erwin-Schoettle-Platz
# (Marienhospital)
# Eszet
# Eugensplatz (Jugendherberge)
# Europaplatz
# Fasanenhof (Bonhoefferkirche)
# Fasanenhof Schelmenwasen
# Fauststraße
# Feuerbach Bahnhof
# Feuerbach Pfostenwäldle (AWO)
# Föhrich
# Freiberg
# Freibergstraße
# Friedrichswahl
# Fürfelder Straße
# Gaisburg
# Geroksruhe
# Giebel
# Glockenstraße (Mahle)
# Gnesener Straße
# Hallschlag
# Hauptbahnhof Arnulf-Klett-Platz
# Hauptfriedhof
# Hedelfingen
# Hedelfinger Straße (Bürocampus Wangen)
# Heidehofstraße
# Herderplatz
# Heslach Vogelrain
# Heumaden
# Heumaden Bockelstraße
# Heutingsheimer Straße
# Himmelsleiter
# Hofen
# Hohensteinstraße
# Hölderlinplatz
# Im Degen
# Inselstraße
# Jurastraße
# Kaltental
# Karl-Olga-Krankenhaus
# Kienbachstraße
# Killesberg
# Kirchtalstraße (Volksbank Zuffenhausen)
# Korntaler Straße
# Kraftwerk Münster
# Kursaal
# Landauer Straße
# Landhaus
# Lapp Kabel
# Lindpaintnerstraße
# Löwen-Markt
# Löwentor (SV SparkassenVersicherung)
# Löwentor (SV SparkassenVersicherung)
# Löwentorbrücke (Diakonie)
# Marienplatz
# Max-Eyth-See
# Maybachstraße
# Mercedesstraße
# Metzstraße (Südwestrundfunk)
# Milchhof (Agentur für Arbeit)
# Millöckerstraße
# Mineralbäder (Naturkundemuseum)
# Mittnachtstraße
# Möhringen Bahnhof
# Möhringen Freibad
# Mönchfeld
# Mühlhausen
# Mühlsteg
# Münster Rathaus
# Münster Viadukt
# NeckarPark (Stadion)
# Neckartor
# Neugereut
# Nordbahnhof (Lotto Baden-Württemberg)
# Nürnberger Straße
# Obere Ziegelei
# Olgaeck
# Ostendplatz
# Österreichischer Platz (WGV-Versicherungen)
# Ostheim (Leo-Vetter-Bad)
# Payerstraße
# Peregrinastraße
# Plieningen (Universität Hohenheim)
# Plieninger Straße
# Pragfriedhof
# Pragfriedhof
# Pragsattel (Mercedes-Benz Bank)
# Raitelsberg
# Rastatter Straße
# Rathaus
# Riedsee
# Riethmüllerhaus
# Rohrer Weg
# Rosenberg-/Seidenstraße (Diakonie-Klinikum)
# Rosensteinbrücke
# Rosensteinbrücke
# Rosensteinpark
# Rotebühlplatz (Das Gerber)
# Ruhbank (Fernsehturm)
# Ruhbank (Fernsehturm)
# Russische Kirche
# Salamanderweg
# Salzäcker
# Salzwiesenstraße
# Schemppstraße
# Schlachthof
# Schloss-/Johannesstraße
# Schlossplatz
# Schlotterbeckstraße
# Schozacher Straße
# Schwab-/Bebelstraße
# Sieglestraße
# Sigmaringer Straße
# Silberwald
# Sillenbuch
# Sonnenberg
# Sportpark Feuerbach
# SSB-Zentrum
# Staatsgalerie
# Stadtbibliothek (Handwerkskammer)
# Stafflenbergstraße (Klinik Charlottenhaus)
# Stammheim
# Steinhaldenfeld
# Stelle
# Stöckach
# Südheimer Platz
# Suttnerstraße
# Tapachstraße
# Uff-Kirchhof
# Untertürkheim Bahnhof
# Untertürkheim Bahnhof
# Vaihingen Bahnhof
# Vaihingen Schillerplatz
# Vaihingen Viadukt
# Vaihinger Straße
# Vogelsang
# Wagrainäcker
# Waldau (Gazi-Stadion)
# Waldeck
# Wallgraben
# Wangen Marktplatz
# Wangener-/Landhausstraße
# Wangener-/Landhausstraße
# Wasenstraße
# Wasenstraße
# Weinsteige
# Wilhelma
# Wilhelm-Geiger-Platz
# Wimpfener Straße
# Wolfbusch
# Zuffenhausen Kelterplatz
# Zuffenhausen Rathaus
# Züricher Straße

# %% [markdown]
# #### Let's check how many venues were returned for each subway station

# %%
stuttgart_venues.groupby('Subway Station').count()
# Out:
#                                              Subway Station Latitude  ...  Venue Category
# Subway Station                                                        ...
# Antwerpener Straße                                                 3  ...               3
# Arndt-/Spittastraße                                                7  ...               7
# Augsburger Platz                                                   5  ...               5
# Auwiesen                                                           5  ...               5
# Bad Cannstatt Wilhelmsplatz                                       47  ...              47
# ...                                                              ...  ...             ...
# Wolfbusch                                                          2  ...               2
# Zuffenhausen Kelterplatz                                           9  ...               9
# Zuffenhausen Rathaus                                              13  ...              13
# Züricher Straße                                                    4  ...               4
# Österreichischer Platz (WGV-Versicherungen)                       12  ...              12
#
# [179 rows x 6 columns]

# %%
stuttgart_venues.head(10)
# Out:
#         Subway Station  ...      Venue Category
# 0   Antwerpener Straße  ...       Metro Station
# 1   Antwerpener Straße  ...         Pastry Shop
# 2   Antwerpener Straße  ...  Advertising Agency
# 3  Arndt-/Spittastraße  ...        Dessert Shop
# 4  Arndt-/Spittastraße  ...        Dessert Shop
# 5  Arndt-/Spittastraße  ...  Spanish Restaurant
# 6  Arndt-/Spittastraße  ...  Turkish Restaurant
# 7  Arndt-/Spittastraße  ...    Kebab Restaurant
# 8  Arndt-/Spittastraße  ...                Café
# 9  Arndt-/Spittastraße  ...   German Restaurant
#
# [10 rows x 7 columns]

# %% [markdown]
# Let's find all restaurant

# %%
stuttgart_restaurant = stuttgart_venues[stuttgart_venues['Venue Category'].map(lambda x: x.find('Restaurant')!=-1)]

# %% [markdown]
# Let's remove all kind of fast food restaurant

# %%
for index, rows in stuttgart_restaurant.iterrows():
    if rows['Venue Category'] in ['Fast Food Restaurant','Comfort Food Restaurant','Doner Restaurant','Kebab Restaurant']:
        stuttgart_restaurant.drop(index, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
stuttgart_restaurant.reset_index(inplace=True)

# %%
stuttgart_restaurant.head(10)
# Out:
#    index  ...             Venue Category
# 0      5  ...         Spanish Restaurant
# 1      6  ...         Turkish Restaurant
# 2      9  ...          German Restaurant
# 3     11  ...           Greek Restaurant
# 4     21  ...           Sushi Restaurant
# 5     26  ...                 Restaurant
# 6     32  ...  Middle Eastern Restaurant
# 7     33  ...           Greek Restaurant
# 8     34  ...                 Restaurant
# 9     37  ...            Thai Restaurant
#
# [10 rows x 8 columns]

# %% [markdown]
# Let's check how many restaurant are there

# %%
stuttgart_restaurant.groupby('Subway Station').count()
# Out:
#                                              index  ...  Venue Category
# Subway Station                                      ...
# Arndt-/Spittastraße                              3  ...               3
# Augsburger Platz                                 1  ...               1
# Bad Cannstatt Wilhelmsplatz                     15  ...              15
# Beethovenstraße                                  1  ...               1
# Berliner Platz (Hohe Straße)                     6  ...               6
# ...                                            ...  ...             ...
# Wilhelm-Geiger-Platz                             6  ...               6
# Wilhelma                                         1  ...               1
# Zuffenhausen Kelterplatz                         1  ...               1
# Zuffenhausen Rathaus                             3  ...               3
# Österreichischer Platz (WGV-Versicherungen)      7  ...               7
#
# [104 rows x 7 columns]

# %% [markdown]
# Let's create a new dataframe with the total number of reataurant

# %%
station_summary = stuttgart_restaurant.groupby('Subway Station')['Venue Category'].count().reset_index()

# %%
station_summary.rename(columns = {'Venue Category':'Total restaurant'}, inplace = True)

# %%
station_summary.head(10)
# Out:
#                   Subway Station  Total restaurant
# 0            Arndt-/Spittastraße                 3
# 1               Augsburger Platz                 1
# 2    Bad Cannstatt Wilhelmsplatz                15
# 3                Beethovenstraße                 1
# 4   Berliner Platz (Hohe Straße)                 6
# 5   Berliner Platz (Liederhalle)                11
# 6                          Blick                 1
# 7                        Botnang                 1
# 8  Bubenbad (IB-Jugendgästehaus)                 1
# 9               Budapester Platz                 1

# %% [markdown]
# Let' check all Sushi restaurant

# %%
sushi_restaurant = stuttgart_restaurant[stuttgart_restaurant['Venue Category']=='Sushi Restaurant']

# %%
sushi_restaurant.head(10)
# Out:
#      index  ...    Venue Category
# 4       21  ...  Sushi Restaurant
# 12      44  ...  Sushi Restaurant
# 44     211  ...  Sushi Restaurant
# 49     233  ...  Sushi Restaurant
# 52     241  ...  Sushi Restaurant
# 60     264  ...  Sushi Restaurant
# 64     275  ...  Sushi Restaurant
# 70     291  ...  Sushi Restaurant
# 149    754  ...  Sushi Restaurant
# 159    784  ...  Sushi Restaurant
#
# [10 rows x 8 columns]

# %% [markdown]
# Let' calculate the total number of Sushi restaurant

# %%
sushi_restaurant_count = sushi_restaurant.groupby('Subway Station')['Venue Category'].count().reset_index()

# %%
sushi_restaurant_count.rename(columns = {'Venue Category':'Total Sushi restaurant'}, inplace = True)

# %%
sushi_restaurant_count.head()
# Out:
#                 Subway Station  Total Sushi restaurant
# 0  Bad Cannstatt Wilhelmsplatz                       2
# 1             Budapester Platz                       1
# 2   Charlottenplatz (Ebene -1)                       2
# 3   Charlottenplatz (Ebene -2)                       2
# 4                 Daimlerplatz                       1

# %% [markdown]
# Add the Sushi restaurant infomation into the data frame

# %%
station_summary = station_summary.merge(sushi_restaurant_count, how='outer',on='Subway Station')

# %%
station_summary = station_summary.fillna(0)

# %% [markdown]
# Let find the location of the subway, we will use mean value in case there are many exit of one station

# %%
station_location = stuttgart_restaurant.groupby('Subway Station')['Subway Station Latitude','Subway Station Longitude'].mean().reset_index()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
station_location.head(10)
# Out:
#                   Subway Station  ...  Subway Station Longitude
# 0            Arndt-/Spittastraße  ...                  9.150833
# 1               Augsburger Platz  ...                  9.230833
# 2    Bad Cannstatt Wilhelmsplatz  ...                  9.215704
# 3                Beethovenstraße  ...                  9.133333
# 4   Berliner Platz (Hohe Straße)  ...                  9.168611
# 5   Berliner Platz (Liederhalle)  ...                  9.168131
# 6                          Blick  ...                  9.242222
# 7                        Botnang  ...                  9.122222
# 8  Bubenbad (IB-Jugendgästehaus)  ...                  9.194722
# 9               Budapester Platz  ...                  9.185833
#
# [10 rows x 3 columns]

# %% [markdown]
# We will define function to caloulate the distance between subway station and city center

# %%
#!pip install pyproj
import pyproj
import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

# %% [markdown]
# Let's calculate the distance between each subway station and city center

# %%
distance_center = pd.DataFrame(columns= ['Distance'])

# %%
for index, rows in station_location.iterrows():
    x1, y1 = lonlat_to_xy(rows['Subway Station Latitude'], rows['Subway Station Longitude'])
    x2, y2 = lonlat_to_xy(latitude,longitude)
    distance = str(calc_xy_distance(x1,y1,x2,y2))
    print(distance)
    
    distance_center = distance_center.append({'Distance': distance}, ignore_index=True)

# %%
distance_center.head()
# Out:
#              Distance
# 0  3891.2501100861095
# 1   7635.814913017591
# 2   5729.130893618349
# 3  6184.7048814929085
# 4  1518.7378735567436

# %%
station_summary.insert(3,column='Distance',value=distance_center)

# %%
station_summary.head(10)
# Out:
#                   Subway Station  ...            Distance
# 0            Arndt-/Spittastraße  ...  3891.2501100861095
# 1               Augsburger Platz  ...   7635.814913017591
# 2    Bad Cannstatt Wilhelmsplatz  ...   5729.130893618349
# 3                Beethovenstraße  ...  6184.7048814929085
# 4   Berliner Platz (Hohe Straße)  ...  1518.7378735567436
# 5   Berliner Platz (Liederhalle)  ...  1573.8432885647078
# 6                          Blick  ...   8469.252067060806
# 7                        Botnang  ...   7654.370042621837
# 8  Bubenbad (IB-Jugendgästehaus)  ...   2061.073677377733
# 9               Budapester Platz  ...  1770.1359677851751
#
# [10 rows x 4 columns]

# %%
station_summary.shape
# Out:
# (104, 4)

# %% [markdown]
# Let normalize the summary of the restaurant and subway station distance infomation

# %%
import pandas as pd
from sklearn import preprocessing
station_summary_norm = station_summary.drop('Subway Station',1)
x = station_summary_norm.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
station_summary_norm = pd.DataFrame(x_scaled)

# %%
station_summary_norm.head()
# Out:
#           0    1         2
# 0  0.111111  0.0  0.334357
# 1  0.000000  0.0  0.669888
# 2  0.777778  1.0  0.499040
# 3  0.000000  0.0  0.539861
# 4  0.277778  0.0  0.121768

# %% [markdown]
# #### Cluster Neighborhoods
# Run *k*-means to cluster the neighborhood into 6 clusters.

# %%
# set number of clusters
kclusters = 6

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(station_summary_norm)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 3, 4, 3, 5, 5, 0, 3, 5, 2], dtype=int32)

# %% [markdown]
# Let's merge the restaurant and location infomation together

# %%
station_summary = station_summary.merge(station_location, on='Subway Station')

station_summary = station_summary.reset_index(drop=True)

station_summary
# Out:
#                                   Subway Station  ...  Subway Station Longitude
# 0                            Arndt-/Spittastraße  ...                  9.150833
# 1                               Augsburger Platz  ...                  9.230833
# 2                    Bad Cannstatt Wilhelmsplatz  ...                  9.215704
# 3                                Beethovenstraße  ...                  9.133333
# 4                   Berliner Platz (Hohe Straße)  ...                  9.168611
# ..                                           ...  ...                       ...
# 99                          Wilhelm-Geiger-Platz  ...                  9.158889
# 100                                     Wilhelma  ...                  9.208056
# 101                     Zuffenhausen Kelterplatz  ...                  9.176111
# 102                         Zuffenhausen Rathaus  ...                  9.174722
# 103  Österreichischer Platz (WGV-Versicherungen)  ...                  9.175556
#
# [104 rows x 6 columns]

# %%
station_summary.insert(1, 'Cluster Labels', kmeans.labels_)

station_summary
# Out:
#                                   Subway Station  ...  Subway Station Longitude
# 0                            Arndt-/Spittastraße  ...                  9.150833
# 1                               Augsburger Platz  ...                  9.230833
# 2                    Bad Cannstatt Wilhelmsplatz  ...                  9.215704
# 3                                Beethovenstraße  ...                  9.133333
# 4                   Berliner Platz (Hohe Straße)  ...                  9.168611
# ..                                           ...  ...                       ...
# 99                          Wilhelm-Geiger-Platz  ...                  9.158889
# 100                                     Wilhelma  ...                  9.208056
# 101                     Zuffenhausen Kelterplatz  ...                  9.176111
# 102                         Zuffenhausen Rathaus  ...                  9.174722
# 103  Österreichischer Platz (WGV-Versicherungen)  ...                  9.175556
#
# [104 rows x 7 columns]

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(station_summary['Subway Station Latitude'], station_summary['Subway Station Longitude'], station_summary['Subway Station'], station_summary['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_29d45ba168ee40b7a0abd54fc9087ff2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_29d45ba168ee40b7a0abd54fc9087ff2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_29d45ba168ee40b7a0abd54fc9087ff2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_29d45ba168ee40b7a0abd54fc9087ff2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.7784485%2C%209.1800132%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_bf44cae6bb234eeda435786487439894%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ## Examine Clusters
# Now, we can explore each cluster.

# %%
station_summary.loc[station_summary['Cluster Labels'] == 0, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                         Subway Station  ...  Subway Station Longitude
# 6                                Blick  ...                  9.242222
# 15                          Dürrlewang  ...                  9.118056
# 17                     Engelboldstraße  ...                  9.128056
# 20                         Europaplatz  ...                  9.160278
# 21            Fasanenhof Schelmenwasen  ...                  9.170278
# 22                         Fauststraße  ...                  9.115278
# 28                         Hedelfingen  ...                  9.254167
# 29                            Heumaden  ...                  9.233889
# 31                               Hofen  ...                  9.222222
# 34                          Jurastraße  ...                  9.117222
# 35                           Kaltental  ...                  9.130000
# 39                     Landauer Straße  ...                  9.123889
# 41                          Lapp Kabel  ...                  9.120833
# 45                        Max-Eyth-See  ...                  9.216389
# 52                   Möhringen Freibad  ...                  9.141389
# 61  Plieningen (Universität Hohenheim)  ...                  9.201667
# 80                 Schlotterbeckstraße  ...                  9.248889
# 90                           Stammheim  ...                  9.156389
# 92             Vaihingen Schillerplatz  ...                  9.113056
# 96                          Wallgraben  ...                  9.125278
# 97                   Wangen Marktplatz  ...                  9.245278
# 98                         Wasenstraße  ...                  9.244722
#
# [22 rows x 6 columns]

# %%
station_summary.loc[station_summary['Cluster Labels'] == 1, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                               Subway Station  ...  Subway Station Longitude
# 0                        Arndt-/Spittastraße  ...                  9.150833
# 14                                 Degerloch  ...                  9.168889
# 18   Erwin-Schoettle-Platz\n(Marienhospital)  ...                  9.160000
# 23                         Feuerbach Bahnhof  ...                  9.168333
# 26                     Glockenstraße (Mahle)  ...                  9.204167
# 36                                Killesberg  ...                  9.171667
# 43      Löwentor (SV SparkassenVersicherung)  ...                  9.190000
# 46                             Maybachstraße  ...                  9.177222
# 47                            Mercedesstraße  ...                  9.211667
# 48              Metzstraße (Südwestrundfunk)  ...                  9.200556
# 49           Mineralbäder (Naturkundemuseum)  ...                  9.205556
# 50                           Mittnachtstraße  ...                  9.190278
# 59                               Ostendplatz  ...                  9.207778
# 60                  Ostheim (Leo-Vetter-Bad)  ...                  9.211111
# 64           Pragsattel (Mercedes-Benz Bank)  ...                  9.183056
# 65                               Raitelsberg  ...                  9.212222
# 68                           Riethmüllerhaus  ...                  9.203889
# 70                          Rosensteinbrücke  ...                  9.210516
# 71                            Rosensteinpark  ...                  9.194722
# 77                               Schlachthof  ...                  9.217500
# 83                              Sieglestraße  ...                  9.177500
# 93                                 Vogelsang  ...                  9.145833
# 95                     Waldau (Gazi-Stadion)  ...                  9.189167
# 99                      Wilhelm-Geiger-Platz  ...                  9.158889
# 100                                 Wilhelma  ...                  9.208056
#
# [25 rows x 6 columns]

# %%
station_summary.loc[station_summary['Cluster Labels'] == 2, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                                   Subway Station  ...  Subway Station Longitude
# 9                               Budapester Platz  ...                  9.185833
# 13                                  Daimlerplatz  ...                  9.218889
# 58                                       Olgaeck  ...                  9.186111
# 72                    Rotebühlplatz (Das Gerber)  ...                  9.172222
# 79                                  Schlossplatz  ...                  9.178889
# 89             Stadtbibliothek (Handwerkskammer)  ...                  9.181111
# 103  Österreichischer Platz (WGV-Versicherungen)  ...                  9.175556
#
# [7 rows x 6 columns]

# %%
station_summary.loc[station_summary['Cluster Labels'] == 3, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                               Subway Station  ...  Subway Station Longitude
# 1                           Augsburger Platz  ...                  9.230833
# 3                            Beethovenstraße  ...                  9.133333
# 7                                    Botnang  ...                  9.122222
# 16                                Elbestraße  ...                  9.212778
# 24                            Freibergstraße  ...                  9.221944
# 25                          Fürfelder Straße  ...                  9.191944
# 30                     Heumaden Bockelstraße  ...                  9.227778
# 32                          Hohensteinstraße  ...                  9.173889
# 37   Kirchtalstraße (Volksbank Zuffenhausen)  ...                  9.170833
# 38                                   Kursaal  ...                  9.222500
# 40                                  Landhaus  ...                  9.165556
# 42                        Lindpaintnerstraße  ...                  9.134167
# 51                         Möhringen Bahnhof  ...                  9.146667
# 53                                  Mühlsteg  ...                  9.215556
# 54                           Münster Rathaus  ...                  9.226667
# 55                           Münster Viadukt  ...                  9.222222
# 56                      NeckarPark (Stadion)  ...                  9.225278
# 62                         Plieninger Straße  ...                  9.156667
# 67                                   Riedsee  ...                  9.150556
# 74                          Salzwiesenstraße  ...                  9.162778
# 75                                 Salzäcker  ...                  9.161944
# 76                             Schemppstraße  ...                  9.218611
# 81                         Schozacher Straße  ...                  9.185000
# 84                        Sigmaringer Straße  ...                  9.153333
# 85                                Sillenbuch  ...                  9.213056
# 86                                Sonnenberg  ...                  9.153611
# 87                       Sportpark Feuerbach  ...                  9.142222
# 94                              Wagrainäcker  ...                  9.212222
# 101                 Zuffenhausen Kelterplatz  ...                  9.176111
# 102                     Zuffenhausen Rathaus  ...                  9.174722
#
# [30 rows x 6 columns]

# %%
station_summary.loc[station_summary['Cluster Labels'] == 4, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                  Subway Station  ...  Subway Station Longitude
# 2   Bad Cannstatt Wilhelmsplatz  ...                  9.215704
# 11   Charlottenplatz (Ebene -1)  ...                  9.182778
# 12   Charlottenplatz (Ebene -2)  ...                  9.183056
# 66                      Rathaus  ...                  9.180000
#
# [4 rows x 6 columns]

# %%
station_summary.loc[station_summary['Cluster Labels'] == 5, station_summary.columns[[0] + list(range(2, station_summary.shape[1]))]]
# Out:
#                                  Subway Station  ...  Subway Station Longitude
# 4                  Berliner Platz (Hohe Straße)  ...                  9.168611
# 5                  Berliner Platz (Liederhalle)  ...                  9.168131
# 8                 Bubenbad (IB-Jugendgästehaus)  ...                  9.194722
# 10                         Börsenplatz (L-Bank)  ...                  9.178333
# 19                 Eugensplatz (Jugendherberge)  ...                  9.190556
# 27              Hauptbahnhof Arnulf-Klett-Platz  ...                  9.180278
# 33                               Hölderlinplatz  ...                  9.158333
# 44                                  Marienplatz  ...                  9.168056
# 57                                    Neckartor  ...                  9.190000
# 63                                 Pragfriedhof  ...                  9.184167
# 69  Rosenberg-/Seidenstraße (Diakonie-Klinikum)  ...                  9.165000
# 73                             Russische Kirche  ...                  9.161389
# 78                      Schloss-/Johannesstraße  ...                  9.162500
# 82                          Schwab-/Bebelstraße  ...                  9.155278
# 88                                Staatsgalerie  ...                  9.187222
# 91                                     Stöckach  ...                  9.195278
#
# [16 rows x 6 columns]

# %% [markdown]
# Let's have a look at the stations considering the total number of restaurant on the map

# %%
# create map
map_restaurant = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, res, res_sushi in zip(station_summary['Subway Station Latitude'], station_summary['Subway Station Longitude'], station_summary['Subway Station'], station_summary['Cluster Labels'], station_summary['Total restaurant'], station_summary['Total Sushi restaurant']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=1 + res*2,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=False,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_restaurant)
       
map_restaurant
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_f57f575a633b49e894505f010566b6a3%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f57f575a633b49e894505f010566b6a3%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_f57f575a633b49e894505f010566b6a3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_f57f575a633b49e894505f010566b6a3%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.7784485%2C%209.1800132%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7d4f598f65f8477f860b015ea8a9038c%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# Let's have a look at the stations considering the total number of Sushi restaurant on the map

# %%
# create map
map_restaurant_Sushi = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, res, res_sushi in zip(station_summary['Subway Station Latitude'], station_summary['Subway Station Longitude'], station_summary['Subway Station'], station_summary['Cluster Labels'], station_summary['Total restaurant'], station_summary['Total Sushi restaurant']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=3 + res_sushi*10,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=False,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_restaurant_Sushi)
       
map_restaurant_Sushi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_ae5da8d4411345e5b32a4b2e00c15715%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ae5da8d4411345e5b32a4b2e00c15715%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_ae5da8d4411345e5b32a4b2e00c15715%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_ae5da8d4411345e5b32a4b2e00c15715%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.7784485%2C%209.1800132%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_88107149b7184c0e899f17cc4f936a9e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Base on the cluster we can find out that cluster 2 and 5 is most intereting for us. Most of the station of Cluster 5 is near the city center stuttgart and has no Sushi restaurant within 300 meter. Cluster 2 is very near from the center and has only one Sushi restaurant nearby.
#
# we can also easily find out, that cluster 0, 1 and 3 are not our candidate, because they are two far from the city center and has very less restaurants nearby. They should be reasons that other don't want to open restaurant there.
# For example, far from shopping area or living area.
#
# Cluster 4 are right in the middle of the city and have a lot or restaurant nearby, but it has already two Sushi restaurant near each of the station. So it would be better to avoid the competions.
#
# Finally, we can choose a place to open the sushi restaurant base on the information we have. I would like to choose Schlossplatz of cluster 5, because it is at the middle if city center that will has a really large nummer of people around for shopping or eating, even there is already one Sushi restaurant there, but the location is perfect. The other choice would be Berliner Platz of cluster 2, it has two stations near each other with large number of restaurant nearby, and there is no Sushi restaurant there.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# In this project we explored and visualized the location date of subway station and restaurant near them. we find out the total number of all restaurant and specially Sushi restautant. We also calculated the distance between subway station and city center. With all the information we used K means as classification method to create different clusters of all subway stations. Among of all these clusters we chosen two of them, which could be the candidates to open a Sushi restaurant.
#
# In this project the location data is used as criteria for opening a restaurant. Of course, there is more criterias needed in the real world. But at least we can have some overview of the restaurants and narrow down the area we are looking for.
#
# I hope this kind of exploration could really help the stakeholder for opening a restaurant.
